# %%
# Gradient descent method
# Initial guess is plotted on x axis and no of iterations on y axis.

import numpy as np 
import matplotlib.pyplot as plt

gr_ds_x = [4,5,2,1,3,6,0.1,1.5,5.6,2.3]
gr_ds_y=[201, 201, 190, 1, 198, 190, 143, 180, 199, 193 ]

plt.scatter(gr_ds_x, gr_ds_y, c="blue")

new_x=[4,5,2,1,3,6,0.1,1.5,5.6,2.3,8,9]
new_y=[7,8,5,4,6,9,7,5,9,6,11,12]
plt.scatter(new_x, new_y, c="red")
